# %% [markdown]
# # Titanic Survival Prediction using Machine Learning
#
# A binary classification project using the **Titanic dataset** to predict whether a passenger survived (`1`) or did not survive (`0`). The notebook primarily demonstrates **Logistic Regression** and also compares it with KNN, Gaussian Naive Bayes, and Decision Tree classifiers.
#
# ## Objective
# Build a machine learning model to predict Titanic passenger survival from demographic and travel-related features.
#
# ## Workflow
# - Load and inspect the Titanic dataset.
# - Remove redundant/non-predictive columns.
# - Handle missing values.
# - Encode categorical variables.
# - Split the data into training and test sets.
# - Standardize features.
# - Train Logistic Regression.
# - Evaluate Logistic Regression using accuracy, confusion matrix, and classification report.
# - Compare its performance with KNN, Gaussian Naive Bayes, and Decision Tree models.
#
# ## Target
# **`survived`** — binary target indicating passenger survival.

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load the Titanic Dataset

# %%
df = sns.load_dataset("titanic")

# %% [markdown]
# ## 3. Preview the Dataset

# %%
df.head()

# %% [markdown]
# ## 4. Inspect Dataset Columns

# %%
df.columns

# %% [markdown]
# ## 5. Inspect Dataset Information

# %%
df.info()

# %% [markdown]
# ## 6. Select Relevant Features

# %%
df = sns.load_dataset("titanic")
df.drop(["deck", "embark_town", "alive", "class", "who", "adult_male"], axis=1, inplace=True)

# %% [markdown]
# ## 7. Check Data Types and Missing Values

# %%
df.info()

# %% [markdown]
# ## 8. Handle Missing Age Values

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %% [markdown]
# ## 9. Handle Missing Embarked Values

# %%
df.dropna(subset=["embarked"], inplace=True)

# %% [markdown]
# ## 10. Encode Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["sex"] = le.fit_transform(df["sex"])
df["embarked"] = le.fit_transform(df["embarked"])

# %% [markdown]
# ## 11. Define Features and Target

# %%
X=df.drop("survived",axis=1)
y=df["survived"]

# %% [markdown]
# ## 12. Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %% [markdown]
# ## 14. Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# ## 15. Evaluate Logistic Regression

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test,y_pred)

# %% [markdown]
# ## 16. Logistic Regression Confusion Matrix

# %%
confusion_matrix(y_test,y_pred)

# %% [markdown]
# ## 17. Logistic Regression Classification Report

# %%
print(classification_report(y_test,y_pred))

# %% [markdown]
# ## 13. Standardize Features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## 18. K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# %% [markdown]
# ## 19. Evaluate KNN

# %%
y_pred_knn = knn.predict(X_test_scaled)
accuracy_score(y_test, y_pred_knn)

# %% [markdown]
# ## 20. KNN Accuracy

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test,y_pred_knn)

# %% [markdown]
# ## 21. KNN Confusion Matrix

# %%
confusion_matrix(y_test,y_pred_knn)

# %% [markdown]
# ## 22. KNN Classification Report

# %%
print(classification_report(y_test,y_pred_knn))

# %% [markdown]
# ## 23. Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ## 24. Train Naive Bayes

# %%
model_NB = GaussianNB()
model_NB.fit(X_train, y_train)

# %% [markdown]
# ## 25. Evaluate Naive Bayes

# %%
y_pred_NB = model_NB.predict(X_test)

# %% [markdown]
# ## 26. Naive Bayes Accuracy

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test,y_pred_NB)

# %% [markdown]
# ## 27. Naive Bayes Confusion Matrix

# %%
confusion_matrix(y_test,y_pred_NB)

# %% [markdown]
# ## 28. Naive Bayes Classification Report

# %%
print(classification_report(y_test,y_pred_NB))

# %% [markdown]
# ## 29. Decision Tree

# %%
#DecisionTree algorithm

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
Model_DT = DecisionTreeClassifier(
    criterion="gini",
    max_depth=3,
    random_state=42
)

# %% [markdown]
# ## 30. Train Decision Tree

# %%
Model_DT.fit(X_train, y_train)

# %% [markdown]
# ## 31. Evaluate Decision Tree

# %%
y_pred_DT = Model_DT.predict(X_test)

# %% [markdown]
# ## 32. Decision Tree Accuracy

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test,y_pred_DT)

# %% [markdown]
# ## 33. Decision Tree Confusion Matrix

# %%
confusion_matrix(y_test,y_pred_DT)

# %% [markdown]
# ## 34. Decision Tree Classification Report

# %%
print(classification_report(y_test,y_pred_DT))

# %% [markdown]
# ## 35. Model Comparison
#
# The original notebook evaluates four classifiers on the same Titanic test set. The recorded test accuracies from the original execution were:
#
# | Model | Test Accuracy |
# |---|---:|
# | Logistic Regression | 80.34% |
# | KNN | 79.21% |
# | Gaussian Naive Bayes | 77.53% |
# | Decision Tree | 82.02% |
#
# > These values are the recorded outputs from the original notebook. The cleaned notebook improves preprocessing consistency by preserving continuous numerical values and using standardized features for Logistic Regression.

# %% [markdown]
# ## Conclusion
#
# The project demonstrates Titanic survival prediction as a binary classification problem. Logistic Regression provides a strong baseline, while the included model comparison shows how other classical machine learning algorithms perform on the same dataset.
